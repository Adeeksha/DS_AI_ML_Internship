# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\ADEEKSHA\Downloads\hiring.csv")

# %%
print("Original Dataset:\n")
print(df)
# Out:
# Original Dataset:
#
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
experience_map = {
    "zero": 0, "one": 1, "two": 2, "three": 3,
    "four": 4, "five": 5, "six": 6, "seven": 7,
    "eight": 8, "nine": 9, "ten": 10,
    "eleven": 11, "twelve": 12
}

# %%
df['experience'] = df['experience'].fillna("zero")
df['experience'] = df['experience'].map(experience_map)

# %%
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(
    df['test_score(out of 10)'].median()
)

# %%
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(
    df['test_score(out of 10)'].median()
)

# %%
X = df[['experience', 'test_score(out of 10)', 'interview_score(out of 10)']]
y = df['salary($)']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("\nModel Coefficients:")
print("Experience Coef:", model.coef_[0])
print("Test Score Coef:", model.coef_[1])
print("Interview Score Coef:", model.coef_[2])
print("Intercept:", model.intercept_)
# Out:
# Model Coefficients:
# Experience Coef: 2812.954876273655
# Test Score Coef: 1845.7059679767092
# Interview Score Coef: 2205.2401746724886
# Intercept: 17737.26346433771

# %%
candidate1 = pd.DataFrame([[2, 9, 6]],
                          columns=X.columns)

# %%
salary1 = model.predict(candidate1)
print("\nPredicted Salary (2 yr, 9 test, 6 interview):", salary1[0])
# Out:
# Predicted Salary (2 yr, 9 test, 6 interview): 53205.96797671034

# %%
candidate2 = pd.DataFrame([[12, 10, 10]],
                          columns=X.columns)

# %%
salary2 = model.predict(candidate2)
print("Predicted Salary (12 yr, 10 test, 10 interview):", salary2[0])
# Out:
# Predicted Salary (12 yr, 10 test, 10 interview): 92002.18340611353

# %%
# Import libraries
import pandas as pd
from sklearn.linear_model import LinearRegression

# ---------------------------
# 1. Load Dataset
# ---------------------------
df = pd.read_csv(r"C:\Users\ADEEKSHA\Downloads\hiring.csv")

print("Original Dataset:\n")
print(df)

# ---------------------------
# 2. Data Cleaning
# ---------------------------

# Convert experience words to numbers
experience_map = {
    "zero": 0, "one": 1, "two": 2, "three": 3,
    "four": 4, "five": 5, "six": 6, "seven": 7,
    "eight": 8, "nine": 9, "ten": 10,
    "eleven": 11, "twelve": 12
}

df['experience'] = df['experience'].fillna("zero")
df['experience'] = df['experience'].map(experience_map)

# Fill missing test score with median
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(
    df['test_score(out of 10)'].median()
)

print("\nCleaned Dataset:\n")
print(df)

# ---------------------------
# 3. Prepare Data
# ---------------------------
X = df[['experience', 'test_score(out of 10)', 'interview_score(out of 10)']]
y = df['salary($)']

# ---------------------------
# 4. Train Model
# ---------------------------
model = LinearRegression()
model.fit(X, y)

# ---------------------------
# 5. Model Details
# ---------------------------
print("\nModel Coefficients:")
print("Experience Coef:", model.coef_[0])
print("Test Score Coef:", model.coef_[1])
print("Interview Score Coef:", model.coef_[2])
print("Intercept:", model.intercept_)

# ---------------------------
# 6. Predictions (No Warning Version)
# ---------------------------

# Candidate 1
candidate1 = pd.DataFrame([[2, 9, 6]],
                          columns=X.columns)

salary1 = model.predict(candidate1)
print("\nPredicted Salary (2 yr, 9 test, 6 interview):", salary1[0])

# Candidate 2
candidate2 = pd.DataFrame([[12, 10, 10]],
                          columns=X.columns)

salary2 = model.predict(candidate2)
print("Predicted Salary (12 yr, 10 test, 10 interview):", salary2[0])
# Out:
# Original Dataset:
#
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000
#
# Cleaned Dataset:
#
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# ...
